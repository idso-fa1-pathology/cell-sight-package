# %%
import re
from datetime import datetime
root = "/rsrch5/home/plm/yshokrollahi/project4/RawDataset"
# Define the file path
file_path = f'{root}/annotaions/MS016S1.txt'

# Function to safely parse coordinate data
def parse_coordinates(coord_string):
    try:
        coordinates = eval(coord_string)
        if isinstance(coordinates, list) and all(isinstance(coord, tuple) for coord in coordinates):
            return coordinates
    except:
        return []

# Function to parse a line
def parse_line(line):
    # Use regex to split line while ignoring commas within square brackets
    parts = re.split(r',(?![^\[\]]*\])', line.strip())

    if len(parts) < 6:
        return None, 'Insufficient data'

    try:
        active = int(parts[0])
        index = int(parts[1])
        data_type = int(parts[2])
        coordinates = parse_coordinates(parts[3])
        colour = parts[4]
        fixed_value = int(parts[5])
    except ValueError as e:
        return None, str(e)

    return {
        'Active': active,
        'Index': index,
        'Type': data_type,
        'Coordinates': coordinates,
        'Color': colour,
        'Fixed Value': fixed_value
    }, None

# Main function to read and categorize data
def read_and_categorize(file_path):
    categorized_data = []
    error_count = 0

    try:
        with open(file_path, 'r') as file:
            for line in file:
                parsed_data, error = parse_line(line)
                if parsed_data:
                    categorized_data.append(parsed_data)
#                     print("Data parsed successfully:", parsed_data)
                elif error:
                    print(f"Skipping line due to parsing error: {line}. Error: {error}")
                    error_count += 1
    except FileNotFoundError:
        print(f"File not found: {file_path}")
    except Exception as e:
        print(f"An error occurred while reading the file: {e}")

    return categorized_data, error_count

# Read and print the categorized data
categorized_data, error_count = read_and_categorize(file_path)

if not categorized_data and error_count == 0:
    print("No data was parsed successfully.")
else:
    print(f"Total number of parsing errors: {error_count}")
# Out:
# Total number of parsing errors: 0

# %%
cd = 0
panck = 0
others = 0
cd_less = 0
for i in range(len(categorized_data)):
    if categorized_data[i]['Color'] == "#00ffff" or categorized_data[i]['Color'] == "#0000ff":
        cd += 1
    elif categorized_data[i]['Color'] == '#c0c0c0':
        cd_less += 1
    elif categorized_data[i]['Color'] == '#ff00ff':
        panck += 1
    else:
        others += 1

# %%
print('cd45+ 95%: ' + str(cd))
print('cd45+ 70%: ' + str(cd_less))
print('panck: ' + str(panck))
print('others: ' + str(others))
# Out:
# cd45+ 95%: 515
# cd45+ 70%: 0
# panck: 531
# others: 540

# %%
points_normalized = []
points_colors = []
for i in range(len(categorized_data)):
    points_normalized.append(categorized_data[i]['Coordinates'][0])
    points_colors.append(categorized_data[i]['Color'])  # Extracting color

    
max(points_normalized, key=lambda x:x[0])
# Out:
# (0.7447405186181105, 0.586109861638924)

# %%
import cv2
import matplotlib.pyplot as plt

# Path to your image
image_path = f"{root}/images/MS016S1.png"
#path to new image with raw format
#image_path = f"{root}/images/MS016S1 OME.ome.tiff"

# Load the image using OpenCV
image = cv2.imread(image_path)

# Get the width and height of the image
height, width, _ = image.shape

# Lists to hold normalized points (x, y) and their respective colors
points_normalized = []
points_colors = []

# Extract coordinates and colors from categorized_data
for i in range(len(categorized_data)):
    points_normalized.append(categorized_data[i]['Coordinates'][0])
    points_colors.append(categorized_data[i]['Color'])  # Extracting color

# Convert normalized coordinates to pixel values
points_pixel = [(int(x * width), int(y * width)) for x, y in points_normalized]

plt.figure(figsize=(10, 10))

# Display the image
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

print(f'all points: {len(points_pixel)}')
points_shown = 0

# Plot the points on the image with their respective colors
for (x, y), color in zip(points_pixel, points_colors):
    plt.scatter(x, y, c=color, marker='o', s=2)  # Using extracted color for each point
    points_shown += 1

print(f' points shown: {points_shown}')

plt.axis("off")
# plt.savefig("/Users/yshokrollahi/Desktop/MD/Project3/dataset/IF/ROIs/28/MS028S1.png")    
# Show the image with points
plt.show()
# Out:
# all points: 1586
#  points shown: 1586

# %%
import re
import cv2
import matplotlib.pyplot as plt

root = "/rsrch5/home/plm/yshokrollahi/project4/RawDataset"
file_path = f'{root}/annotaions/MS023S1.txt'
old_image_path = f"{root}/images/MS023S1.png"
new_image_path = f"{root}/ome-png/MS023S1.png"

# Function to safely parse coordinate data
def parse_coordinates(coord_string):
    try:
        coordinates = eval(coord_string)
        if isinstance(coordinates, list) and all(isinstance(coord, tuple) for coord in coordinates):
            return coordinates
    except:
        return []

# Function to parse a line
def parse_line(line):
    parts = re.split(r',(?![^\[\]]*\])', line.strip())
    if len(parts) < 6:
        return None, 'Insufficient data'
    try:
        active = int(parts[0])
        index = int(parts[1])
        data_type = int(parts[2])
        coordinates = parse_coordinates(parts[3])
        colour = parts[4]
        fixed_value = int(parts[5])
    except ValueError as e:
        return None, str(e)
    return {
        'Active': active,
        'Index': index,
        'Type': data_type,
        'Coordinates': coordinates,
        'Color': colour,
        'Fixed Value': fixed_value
    }, None

# Main function to read and categorize data
def read_and_categorize(file_path):
    categorized_data = []
    error_count = 0
    try:
        with open(file_path, 'r') as file:
            for line in file:
                parsed_data, error = parse_line(line)
                if parsed_data:
                    categorized_data.append(parsed_data)
                elif error:
                    print(f"Skipping line due to parsing error: {line}. Error: {error}")
                    error_count += 1
    except FileNotFoundError:
        print(f"File not found: {file_path}")
    except Exception as e:
        print(f"An error occurred while reading the file: {e}")
    return categorized_data, error_count

# Read and print the categorized data
categorized_data, error_count = read_and_categorize(file_path)
if not categorized_data and error_count == 0:
    print("No data was parsed successfully.")
else:
    print(f"Total number of parsing errors: {error_count}")

# Load the old and new images
old_image = cv2.imread(old_image_path)
new_image = cv2.imread(new_image_path)

# Get the width and height of the images
old_height, old_width, _ = old_image.shape
new_height, new_width, _ = new_image.shape

# Calculate scaling factor based on width
scale_factor = new_width / old_width

# Lists to hold points and their respective colors
points_normalized = []
points_colors = []
# Out:
# Total number of parsing errors: 0

# %%
# Extract coordinates and colors from categorized_data
for i in range(len(categorized_data)):
    points_normalized.append(categorized_data[i]['Coordinates'][0])
    points_colors.append(categorized_data[i]['Color'])  # Extracting color

# Convert coordinates to pixel values for the old image
points_pixel_old = [(int(x * old_width), int(y * old_width)) for x, y in points_normalized]

# Convert coordinates to pixel values for the new image using the scale factor
points_pixel_new = [(int(x * new_width), int(y * new_height)) for x, y in points_normalized]

# %%
print(old_width)
print(new_width)

print(old_height)
print(new_height)

print(new_width / old_width)
print(new_height / old_height)
# Out:
# 10511
# 16384
# 17639
# 16384
# 1.5587479783084388
# 0.9288508418844605

# %%
# Plot points on the old image
plt.figure(figsize=(10, 10))
plt.imshow(cv2.cvtColor(old_image, cv2.COLOR_BGR2RGB))
for (x, y), color in zip(points_pixel_old, points_colors):
    plt.scatter(x, y, c=color, marker='o', s=2)
plt.title("Old Image with Annotations")
plt.axis("off")
plt.show()

# Plot points on the new image
plt.figure(figsize=(10, 10))
plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB))
for (x, y), color in zip(points_pixel_new, points_colors):
    plt.scatter(x, y, c=color, marker='o', s=2)
plt.title("New Image with Annotations")
plt.axis("off")
plt.show()

# %% [markdown]
# ##Ome tiff to png

# %%
import os
import cv2
import tifffile as tiff
import numpy as np

# Paths
root = "/rsrch5/home/plm/yshokrollahi/project4/RawDataset"
ome_tiff_path = f"{root}/images/MOS044S1 OME.ome.tiff"
output_folder = f"{root}/ome-png"

# Ensure the output directory exists
os.makedirs(output_folder, exist_ok=True)

# Read the OME-TIFF image using tifffile
ome_image = tiff.imread(ome_tiff_path)

# Check the shape to ensure it is as expected
print(f"Image shape: {ome_image.shape}")
print(f"Image dtype: {ome_image.dtype}")

# Normalize each channel for saving
channels = []
for i in range(ome_image.shape[0]):
    normalized_channel = cv2.normalize(ome_image[i], None, 0, 255, cv2.NORM_MINMAX).astype('uint8')
    channels.append(normalized_channel)

# Stack channels to form an RGB image
rgb_image = cv2.merge(channels)

# Define the output path for the PNG file
output_png_path = os.path.join(output_folder, "MS044S1.png")

# Save the image as PNG
cv2.imwrite(output_png_path, rgb_image)

print(f"OME-TIFF image has been converted to PNG and saved at: {output_png_path}")

# %% [markdown]
# create patches from png

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img_name = "MS079S1"
# Paths
root = "/rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png"
png_image_path = f"{root}/{img_name}.png"
output_folder = f"{root}/patches"

# Ensure the output directory exists
os.makedirs(output_folder, exist_ok=True)

# Read the PNG image
image = cv2.imread(png_image_path)

# Manually specify the bounding box coordinates
x, y = 5000, 5000  # Top-left corner
w, h = 15000, 15000  # Width and height of the bounding box

# Draw the bounding box on the image for visualization
image_with_box = image.copy()
cv2.rectangle(image_with_box, (x, y), (x+w, y+h), (0, 255, 0), 2)
plt.figure(figsize=(10, 10))
plt.imshow(cv2.cvtColor(image_with_box, cv2.COLOR_BGR2RGB))
plt.title("Manually Specified Bounding Box around Tissue")
plt.axis("off")
plt.show()

# Save the image with bounding box for verification
cv2.imwrite(os.path.join(output_folder, "image_with_manual_box.png"), image_with_box)

print(f"Manually specified bounding box coordinates: x={x}, y={y}, width={w}, height={h}")
print("Image with manually specified bounding box has been saved for verification.")

# Define patch size
patch_size = 640

# Function to extract patches
def extract_patches(image, x, y, w, h, patch_size):
    patches = []
    patch_coords = []
    for i in range(y, y+h, patch_size):
        for j in range(x, x+w, patch_size):
            if i + patch_size > y + h:  # If patch exceeds the tissue region in height
                i = y + h - patch_size
            if j + patch_size > x + w:  # If patch exceeds the tissue region in width
                j = x + w - patch_size
            patch = image[i:i+patch_size, j:j+patch_size]
            patches.append(patch)
            patch_coords.append((i, j))
            # Save the patch as a separate file
            patch_filename = f"patch_{i}_{j}.png"
            patch_output_path = os.path.join(output_folder, patch_filename)
            cv2.imwrite(patch_output_path, patch)
            if j + patch_size >= x + w:  # Move to the next row if patch exceeds width
                break
        if i + patch_size >= y + h:  # End if patch exceeds height
            break
    return patches, patch_coords

# Extract patches
patches, patch_coords = extract_patches(image, x, y, w, h, patch_size)

print(f"Extracted {len(patches)} patches.")

# Function to check if a patch is completely black
def is_patch_black(patch):
    return np.all(patch == 0)

# Delete completely black patches and patches under 200 KB
size_threshold = 200 * 1024  # 200 KB in bytes

for i, (patch, coords) in enumerate(zip(patches, patch_coords)):
    patch_filename = f"patch_{coords[0]}_{coords[1]}.png"
    patch_output_path = os.path.join(output_folder, patch_filename)
    if is_patch_black(patch) or os.path.getsize(patch_output_path) < size_threshold:
        os.remove(patch_output_path)
        print(f"Deleted patch: {patch_output_path}")

print("Black patches and patches under 200 KB have been deleted.")

# Rename remaining patches
remaining_patches_files = sorted([f for f in os.listdir(output_folder) if f.startswith("patch_")])
for idx, filename in enumerate(remaining_patches_files, start=1):
    old_path = os.path.join(output_folder, filename)
    new_filename = f"{img_name}_roi_{idx}.png"
    new_path = os.path.join(output_folder, new_filename)
    os.rename(old_path, new_path)
    print(f"Renamed {old_path} to {new_path}")

print("Remaining patches have been renamed.")

# Visualize some of the remaining patches
for idx, patch_filename in enumerate(remaining_patches_files[:5]):
    patch_path = os.path.join(output_folder, f"{img_name}_roi_{idx + 1}.png")
    patch = cv2.imread(patch_path)
    plt.figure(figsize=(5, 5))
    plt.imshow(cv2.cvtColor(patch, cv2.COLOR_BGR2RGB))
    plt.title(f"Remaining Patch {idx + 1}")
    plt.axis("off")
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[137], line 15
#      12 os.makedirs(output_folder, exist_ok=True)
#      14 # Read the PNG image
# ---> 15 image = cv2.imread(png_image_path)
#      17 # Manually specify the bounding box coordinates
#      18 x, y = 5000, 5000  # Top-left corner
#
# error: OpenCV(4.9.0) /io/opencv/modules/imgcodecs/src/loadsave.cpp:79: error: (-215:Assertion failed) pixels <= CV_IO_MAX_IMAGE_PIXELS in function 'validateInputImageSize'

# %%
import cv2
import numpy as np
import os
import matplotlib.pyplot as plt
from PIL import Image
img_name = "MS044S1"
# Paths
# Override the decompression bomb protection
Image.MAX_IMAGE_PIXELS = None
root = "/rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png"
png_image_path = f"{root}/{img_name}.png"
output_folder = f"{root}/patches"

# Ensure the output directory exists
os.makedirs(output_folder, exist_ok=True)

# Read the PNG image using Pillow to handle large images
image = Image.open(png_image_path)
image = np.array(image)

# Manually specify the bounding box coordinates
x, y = 6000, 6000  # Top-left corner
w, h = 20000, 20000  # Width and height of the bounding box

# Draw the bounding box on the image for visualization
image_with_box = image.copy()
cv2.rectangle(image_with_box, (x, y), (x+w, y+h), (0, 255, 0), 2)
plt.figure(figsize=(10, 10))
plt.imshow(cv2.cvtColor(image_with_box, cv2.COLOR_BGR2RGB))
plt.title("Manually Specified Bounding Box around Tissue")
plt.axis("off")
plt.show()

# Save the image with bounding box for verification
cv2.imwrite(os.path.join(output_folder, "image_with_manual_box.png"), image_with_box)

print(f"Manually specified bounding box coordinates: x={x}, y={y}, width={w}, height={h}")
print("Image with manually specified bounding box has been saved for verification.")

# Define patch size
patch_size = 640

# Function to extract patches
def extract_patches(image, x, y, w, h, patch_size):
    patches = []
    patch_coords = []
    for i in range(y, y+h, patch_size):
        for j in range(x, x+w, patch_size):
            if i + patch_size > y + h:  # If patch exceeds the tissue region in height
                i = y + h - patch_size
            if j + patch_size > x + w:  # If patch exceeds the tissue region in width
                j = x + w - patch_size
            patch = image[i:i+patch_size, j:j+patch_size]
            patches.append(patch)
            patch_coords.append((i, j))
            # Save the patch as a separate file
            patch_filename = f"patch_{i}_{j}.png"
            patch_output_path = os.path.join(output_folder, patch_filename)
            cv2.imwrite(patch_output_path, patch)
            if j + patch_size >= x + w:  # Move to the next row if patch exceeds width
                break
        if i + patch_size >= y + h:  # End if patch exceeds height
            break
    return patches, patch_coords

# Extract patches
patches, patch_coords = extract_patches(image, x, y, w, h, patch_size)

print(f"Extracted {len(patches)} patches.")

# Function to check if a patch is completely black
def is_patch_black(patch):
    return np.all(patch == 0)

# Delete completely black patches and patches under 200 KB
size_threshold = 200 * 1024  # 200 KB in bytes

for i, (patch, coords) in enumerate(zip(patches, patch_coords)):
    patch_filename = f"patch_{coords[0]}_{coords[1]}.png"
    patch_output_path = os.path.join(output_folder, patch_filename)
    if is_patch_black(patch) or os.path.getsize(patch_output_path) < size_threshold:
        os.remove(patch_output_path)
        print(f"Deleted patch: {patch_output_path}")

print("Black patches and patches under 200 KB have been deleted.")

# Rename remaining patches
remaining_patches_files = sorted([f for f in os.listdir(output_folder) if f.startswith("patch_")])
for idx, filename in enumerate(remaining_patches_files, start=1):
    old_path = os.path.join(output_folder, filename)
    new_filename = f"{img_name}_roi_{idx}.png"
    new_path = os.path.join(output_folder, new_filename)
    os.rename(old_path, new_path)
    print(f"Renamed {old_path} to {new_path}")

print("Remaining patches have been renamed.")

# Visualize some of the remaining patches
for idx, patch_filename in enumerate(remaining_patches_files[:5]):
    patch_path = os.path.join(output_folder, f"{img_name}_roi_{idx + 1}.png")
    patch = cv2.imread(patch_path)
    plt.figure(figsize=(5, 5))
    plt.imshow(cv2.cvtColor(patch, cv2.COLOR_BGR2RGB))
    plt.title(f"Remaining Patch {idx + 1}")
    plt.axis("off")
    plt.show()
# Out:
# Manually specified bounding box coordinates: x=6000, y=6000, width=20000, height=20000
# Image with manually specified bounding box has been saved for verification.
# Extracted 1024 patches.
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6000_6000.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6000_6640.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6000_7280.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6000_7920.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6000_8560.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6000_9200.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6000_9840.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6000_10480.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6000_11120.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6000_11760.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6000_12400.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6000_13040.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6000_15600.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6000_16240.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6000_16880.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6000_17520.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6000_18160.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6000_18800.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6000_19440.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6000_20080.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6000_20720.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6000_21360.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6000_22000.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6000_22640.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6000_23280.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6000_23920.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6000_24560.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6000_25200.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6000_25360.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6640_6000.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6640_6640.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6640_7280.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6640_7920.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6640_8560.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6640_9200.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6640_9840.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6640_10480.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6640_11120.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6640_16240.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6640_16880.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6640_17520.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6640_18160.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6640_18800.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6640_19440.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6640_20080.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6640_20720.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6640_21360.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6640_22000.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6640_22640.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6640_23280.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6640_23920.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6640_24560.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6640_25200.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6640_25360.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7280_6000.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7280_6640.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7280_7280.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7280_7920.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7280_8560.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7280_9200.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7280_9840.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7280_10480.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7280_11120.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7280_16880.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7280_17520.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7280_18160.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7280_18800.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7280_19440.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7280_20080.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7280_20720.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7280_21360.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7280_22000.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7280_22640.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7280_23280.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7280_23920.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7280_24560.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7280_25200.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7280_25360.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7920_6000.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7920_6640.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7920_7280.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7920_7920.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7920_8560.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7920_9200.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7920_9840.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7920_10480.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7920_11120.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7920_11760.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7920_12400.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7920_16880.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7920_19440.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7920_20080.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7920_20720.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7920_21360.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7920_22000.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7920_22640.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7920_23280.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7920_23920.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7920_24560.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7920_25200.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7920_25360.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_8560_6000.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_8560_6640.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_8560_7280.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_8560_7920.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_8560_8560.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_8560_9200.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_8560_9840.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_8560_10480.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_8560_11120.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_8560_11760.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_8560_12400.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_8560_19440.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_8560_20080.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_8560_20720.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_8560_21360.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_8560_22000.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_8560_22640.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_8560_23280.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_8560_23920.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_8560_24560.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_8560_25200.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_8560_25360.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9200_6000.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9200_6640.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9200_7280.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9200_7920.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9200_8560.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9200_9200.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9200_9840.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9200_10480.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9200_11120.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9200_11760.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9200_12400.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9200_21360.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9200_22000.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9200_22640.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9200_23280.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9200_23920.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9200_24560.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9200_25200.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9200_25360.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9840_6000.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9840_6640.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9840_7280.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9840_7920.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9840_8560.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9840_9200.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9840_9840.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9840_11120.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9840_11760.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9840_12400.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9840_13040.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9840_22000.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9840_22640.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9840_23280.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9840_23920.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9840_24560.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9840_25200.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9840_25360.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_10480_6000.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_10480_6640.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_10480_7280.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_10480_7920.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_10480_8560.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_10480_9200.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_10480_9840.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_10480_10480.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_10480_11760.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_10480_12400.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_10480_13040.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_10480_22000.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_10480_22640.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_10480_23280.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_10480_23920.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_10480_24560.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_10480_25200.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_10480_25360.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_11120_6000.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_11120_6640.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_11120_7280.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_11120_7920.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_11120_8560.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_11120_9200.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_11120_9840.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_11120_10480.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_11120_11760.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_11120_12400.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_11120_13040.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_11120_16880.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_11120_22640.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_11120_23280.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_11120_23920.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_11120_24560.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_11120_25200.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_11120_25360.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_11760_6000.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_11760_6640.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_11760_7280.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_11760_7920.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_11760_8560.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_11760_10480.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_11760_11120.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_11760_11760.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_11760_12400.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_11760_13040.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_11760_16880.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_11760_18160.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_11760_18800.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_11760_22000.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_11760_22640.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_11760_23280.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_11760_23920.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_11760_24560.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_11760_25200.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_11760_25360.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_12400_6000.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_12400_6640.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_12400_7280.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_12400_7920.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_12400_9840.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_12400_10480.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_12400_11120.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_12400_11760.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_12400_12400.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_12400_13040.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_12400_15600.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_12400_16240.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_12400_16880.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_12400_17520.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_12400_18160.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_12400_18800.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_12400_19440.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_12400_20720.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_12400_21360.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_12400_22000.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_12400_22640.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_12400_23280.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_12400_23920.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_12400_24560.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_12400_25200.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_12400_25360.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_13040_6000.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_13040_6640.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_13040_7280.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_13040_9200.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_13040_9840.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_13040_10480.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_13040_11120.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_13040_11760.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_13040_12400.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_13040_13040.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_13040_13680.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_13040_16240.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_13040_16880.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_13040_17520.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_13040_18160.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_13040_18800.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_13040_19440.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_13040_20080.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_13040_20720.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_13040_21360.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_13040_22000.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_13040_22640.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_13040_23280.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_13040_23920.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_13040_24560.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_13040_25200.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_13040_25360.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_13680_6000.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_13680_6640.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_13680_7280.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_13680_9200.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_13680_9840.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_13680_10480.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_13680_11120.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_13680_11760.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_13680_12400.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_13680_13040.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_13680_13680.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_13680_14320.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_13680_16240.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_13680_16880.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_13680_17520.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_13680_18160.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_13680_18800.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_13680_19440.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_13680_20080.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_13680_20720.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_13680_21360.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_13680_22000.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_13680_22640.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_13680_23280.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_13680_23920.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_13680_24560.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_13680_25200.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_13680_25360.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_14320_6000.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_14320_6640.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_14320_7280.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_14320_7920.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_14320_9200.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_14320_9840.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_14320_10480.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_14320_11120.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_14320_11760.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_14320_12400.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_14320_13040.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_14320_13680.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_14320_14320.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_14320_14960.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_14320_15600.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_14320_16240.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_14320_16880.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_14320_17520.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_14320_18160.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_14320_19440.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_14320_20080.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_14320_20720.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_14320_21360.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_14320_22000.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_14320_22640.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_14320_23280.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_14320_23920.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_14320_24560.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_14320_25200.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_14320_25360.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_14960_6000.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_14960_6640.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_14960_7280.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_14960_9200.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_14960_9840.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_14960_10480.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_14960_11120.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_14960_11760.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_14960_12400.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_14960_13040.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_14960_13680.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_14960_14320.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_14960_14960.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_14960_15600.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_14960_16240.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_14960_16880.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_14960_17520.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_14960_18160.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_14960_21360.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_14960_22000.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_14960_22640.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_14960_23280.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_14960_23920.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_14960_24560.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_14960_25200.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_14960_25360.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_15600_6000.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_15600_6640.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_15600_7920.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_15600_8560.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_15600_9200.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_15600_9840.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_15600_10480.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_15600_11120.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_15600_11760.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_15600_12400.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_15600_13040.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_15600_13680.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_15600_14320.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_15600_14960.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_15600_15600.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_15600_16240.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_15600_16880.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_15600_22000.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_15600_22640.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_15600_23280.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_15600_23920.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_15600_24560.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_15600_25200.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_15600_25360.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_16240_6000.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_16240_6640.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_16240_7280.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_16240_7920.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_16240_8560.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_16240_9200.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_16240_9840.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_16240_10480.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_16240_11120.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_16240_11760.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_16240_12400.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_16240_13040.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_16240_13680.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_16240_14320.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_16240_14960.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_16240_15600.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_16240_16240.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_16240_22000.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_16240_22640.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_16240_23280.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_16240_23920.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_16240_24560.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_16240_25200.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_16240_25360.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_16880_6000.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_16880_6640.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_16880_7280.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_16880_7920.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_16880_8560.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_16880_9200.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_16880_9840.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_16880_10480.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_16880_11120.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_16880_11760.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_16880_12400.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_16880_13040.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_16880_13680.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_16880_14320.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_16880_14960.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_16880_15600.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_16880_16240.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_16880_18800.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_16880_19440.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_16880_22640.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_16880_23280.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_16880_23920.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_16880_24560.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_16880_25200.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_16880_25360.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_17520_6000.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_17520_6640.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_17520_7280.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_17520_7920.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_17520_8560.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_17520_9200.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_17520_9840.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_17520_10480.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_17520_11120.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_17520_11760.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_17520_12400.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_17520_13040.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_17520_13680.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_17520_14320.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_17520_14960.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_17520_15600.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_17520_16240.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_17520_18800.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_17520_22000.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_17520_22640.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_17520_23280.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_17520_23920.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_17520_24560.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_17520_25200.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_17520_25360.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_18160_6000.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_18160_6640.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_18160_7280.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_18160_7920.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_18160_8560.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_18160_13680.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_18160_14320.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_18160_14960.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_18160_15600.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_18160_16240.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_18160_16880.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_18160_17520.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_18160_18160.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_18160_20720.png
# Deleted patch: /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_18160_22000.png
# ...
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_25200_15600.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_182.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_25200_16240.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_183.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_25200_16880.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_184.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_25200_17520.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_185.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_25200_18160.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_186.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_25200_18800.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_187.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_25200_19440.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_188.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_25200_20080.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_189.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_25360_10480.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_190.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_25360_12400.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_191.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_25360_13040.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_192.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_25360_13680.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_193.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_25360_14320.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_194.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_25360_15600.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_195.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_25360_16240.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_196.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_25360_16880.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_197.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_25360_17520.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_198.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_25360_18160.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_199.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_25360_18800.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_200.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_25360_19440.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_201.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_25360_20080.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_202.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_25360_20720.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_203.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6000_13680.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_204.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6000_14320.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_205.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6000_14960.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_206.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6640_11760.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_207.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6640_12400.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_208.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6640_13040.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_209.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6640_13680.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_210.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6640_14320.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_211.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6640_14960.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_212.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_6640_15600.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_213.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7280_11760.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_214.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7280_12400.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_215.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7280_13040.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_216.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7280_13680.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_217.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7280_14320.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_218.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7280_14960.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_219.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7280_15600.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_220.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7280_16240.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_221.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7920_13040.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_222.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7920_13680.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_223.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7920_14320.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_224.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7920_14960.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_225.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7920_15600.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_226.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7920_16240.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_227.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7920_17520.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_228.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7920_18160.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_229.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_7920_18800.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_230.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_8560_13040.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_231.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_8560_13680.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_232.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_8560_14320.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_233.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_8560_14960.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_234.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_8560_15600.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_235.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_8560_16240.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_236.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_8560_16880.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_237.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_8560_17520.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_238.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_8560_18160.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_239.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_8560_18800.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_240.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9200_13040.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_241.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9200_13680.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_242.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9200_14320.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_243.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9200_14960.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_244.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9200_15600.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_245.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9200_16240.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_246.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9200_16880.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_247.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9200_17520.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_248.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9200_18160.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_249.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9200_18800.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_250.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9200_19440.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_251.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9200_20080.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_252.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9200_20720.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_253.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9840_10480.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_254.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9840_13680.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_255.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9840_14320.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_256.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9840_14960.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_257.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9840_15600.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_258.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9840_16240.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_259.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9840_16880.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_260.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9840_17520.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_261.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9840_18160.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_262.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9840_18800.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_263.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9840_19440.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_264.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9840_20080.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_265.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9840_20720.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_266.png
# Renamed /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/patch_9840_21360.png to /rsrch5/home/plm/yshokrollahi/project4/RawDataset/ome-png/patches/MS044S1_roi_267.png
# Remaining patches have been renamed.
