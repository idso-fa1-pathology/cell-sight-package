# %% [markdown]
# # Reading Annotaions

# %%
# image 16
# # New known points in the old image (width = 15407, height = 13992)
# p1_old = np.array([0.13884484972986444 * 15407, 0.5178713216986861 * 15407])
# p2_old = np.array([0.7010496245265906 * 15407, 0.6857380080869139 * 15407])

# # New known points in the new image (width = 32768, height = 32768)
# p1_new = np.array([0.16000369968169129 * 32768, 0.5503012457636682 * 32768])
# p2_new = np.array([0.6891622814400874 * 32768, 0.7082545182013625 * 32768])
# # Transform coordinates
# width1 = 15407
# width2 = 32768

# image 23
# # Known points in the first image (width = 10511)
# p1_old = np.array([0.18319558536996872 * 10511, 0.4175176958359143 * 10511])
# p2_old = np.array([0.44720853752805334 * 10511, 0.6815269638613446 * 10511])

# # Known points in the second image (width = 16384)
# p1_new = np.array([0.2964984303713581 * 16384, 0.20486673050157883 * 16384])
# p2_new = np.array([0.4660897028652409 * 16384, 0.37439425586304204 * 16384])

# # Transform coordinates
# width1 = 10511
# width2 = 16384


# image 28

# # New known points in the old image (width = 12378, height = 15012)
# p1_old = np.array([0.5323592572968489 * 12378, 1.0432757464268654 * 12378])
# p2_old = np.array([0.9232607042284997 * 12378, 0.5662726131234669 * 12378])

# # New known points in the new image (width = 32768, height = 32768)
# p1_new = np.array([0.5243333102252147 * 32768, 0.820522961647639 * 32768])
# p2_new = np.array([0.8200518868418736 * 32768, 0.4598016883907578 * 32768])

# # Transform coordinates
# width1 = 12378
# width2 = 32768

# image 29

# # New known points in the old image (width = 16397, height = 16397)
# p1_old = np.array([0.05114284213382567 * 16397, 0.4002379126459319 * 16397])
# p2_old = np.array([0.8230237787458654 * 16397, 0.6605354634458589 * 16397])


# # New known points in the new image (width = 32768, height = 32768)
# p1_new = np.array([0.050279676681006115 * 32768, 0.49619859081367734 * 32768])
# p2_new = np.array([0.8234977665244849 * 32768, 0.7568691523183926 * 32768])

# # # Transform coordinates
# # width1 = 16397
# # width2 = 32768

# image 35

# # Known points in the old image (width = 16863)
# p1_old = np.array([0.4063482688663783 * 16863, 1.2744512166511885 * 16863])
# p2_old = np.array([0.03603581560411739 * 16863, 0.9994550978086241 * 16863])

# # Known points in the new image (width = 32768)
# p1_new = np.array([0.4517154446956508 * 32768, 0.7849706467726981 * 32768])
# p2_new = np.array([0.26097371319696044 * 32768, 0.6433136236180348 * 32768])

# # # Transform coordinates
# # width1 = 16863
# # width2 = 32768

# # image 38


# # Known points in the old image (width = 11380)
# p1_old = np.array([0.022304532353241945 * 11380, 0.941908502262405 * 11380])
# p2_old = np.array([0.6594887308534805 * 11380, 0.859893126731165 * 11380])


# # Known points in the new image (width = 16384)
# p1_new = np.array([0.1677566319301885 * 16384, 0.6940139430968255 * 16384])
# p2_new = np.array([0.6108605253843963 * 16384, 0.6369897015643509 * 16384])

# # Transform coordinates
# width1 = 11380
# width2 = 16384

# %%
import re
import numpy as np
from scipy.optimize import least_squares

# Function to safely parse coordinate data
def parse_coordinates(coord_string):
    try:
        coordinates = eval(coord_string)
        if isinstance(coordinates, list) and all(isinstance(coord, tuple) for coord in coordinates):
            return coordinates
    except:
        return []

# Function to parse a line
def parse_line(line):
    # Use regex to split line while ignoring commas within square brackets
    parts = re.split(r',(?![^\[\]]*\])', line.strip())

    if len(parts) < 6:
        return None, 'Insufficient data'

    try:
        active = int(parts[0])
        index = int(parts[1])
        data_type = int(parts[2])
        coordinates = parse_coordinates(parts[3])
        colour = parts[4]
        fixed_value = int(parts[5])
    except ValueError as e:
        return None, str(e)

    return {
        'Active': active,
        'Index': index,
        'Type': data_type,
        'Coordinates': coordinates,
        'Color': colour,
        'Fixed Value': fixed_value
    }, None

# Main function to read and categorize data
def read_and_categorize(file_path):
    categorized_data = []
    error_count = 0

    try:
        with open(file_path, 'r') as file:
            for line in file:
                parsed_data, error = parse_line(line)
                if parsed_data:
                    categorized_data.append(parsed_data)
                elif error:
                    print(f"Skipping line due to parsing error: {line}. Error: {error}")
                    error_count += 1
    except FileNotFoundError:
        print(f"File not found: {file_path}")
    except Exception as e:
        print(f"An error occurred while reading the file: {e}")

    return categorized_data, error_count


# Known points in the old image (width = 11380)
p1_old = np.array([0.022304532353241945 * 11380, 0.941908502262405 * 11380])
p2_old = np.array([0.6594887308534805 * 11380, 0.859893126731165 * 11380])


# Known points in the new image (width = 16384)
p1_new = np.array([0.1677566319301885 * 16384, 0.6940139430968255 * 16384])
p2_new = np.array([0.6108605253843963 * 16384, 0.6369897015643509 * 16384])

# Function to model the affine transformation
def affine_transform(params, src, dst):
    a, b, tx, ty = params
    transformed = np.dot(np.array([[a, -b], [b, a]]), src.T).T + [tx, ty]
    return (transformed - dst).ravel()

# Initial guess for the parameters
initial_params = [1, 0, 0, 0]

# Solve for the transformation parameters
result = least_squares(affine_transform, initial_params, args=(np.array([p1_old, p2_old]), np.array([p1_new, p2_new])))
a, b, tx, ty = result.x

# Define the affine transformation matrix
transformation_matrix = np.array([[a, 0, tx], [0, a, ty]])

# Function to apply the affine transformation to a point
def apply_affine_transform(point, matrix):
    point_homogeneous = np.append(point, 1)  # Convert to homogeneous coordinates
    transformed_point = np.dot(matrix, point_homogeneous)
    return transformed_point[:2]

# Function to transform all coordinates in the categorized data
def transform_coordinates(categorized_data, width1, width2, matrix):
    for data in categorized_data:
        new_coordinates = []
        for coord in data['Coordinates']:
            point = np.array([coord[0] * width1, coord[1] * width1])
            transformed_point = apply_affine_transform(point, matrix)
            new_normalized = (transformed_point[0] / width2, transformed_point[1] / width2)
            new_coordinates.append(new_normalized)
        data['Coordinates'] = new_coordinates
    return categorized_data

# Read and categorize data
file_path = f'/rsrch5/home/plm/yshokrollahi/project4/RawDataset/annotaions/MS038S1.txt'
categorized_data, error_count = read_and_categorize(file_path)

# Transform coordinates
width1 = 11380
width2 = 16384
transformed_data = transform_coordinates(categorized_data, width1, width2, transformation_matrix)

# Output the transformed data
for data in transformed_data:
    print(data)

if not categorized_data and error_count == 0:
    print("No data was parsed successfully.")
else:
    print(f"Total number of parsing errors: {error_count}")
# Out:
# {'Active': 1, 'Index': 1, 'Type': 6, 'Coordinates': [(0.35874631082581876, 0.3347597742990995), (0.35874631082581876, 0.3347597742990995)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 2, 'Type': 6, 'Coordinates': [(0.3588574160227418, 0.33620414185909825), (0.3588574160227418, 0.33620414185909825)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 3, 'Type': 6, 'Coordinates': [(0.3642460180735062, 0.3387040087898652), (0.3642460180735062, 0.3387040087898652)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 4, 'Type': 6, 'Coordinates': [(0.36902354154119427, 0.3469813459606271), (0.36902354154119427, 0.3469813459606271)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 5, 'Type': 6, 'Coordinates': [(0.36696809539811914, 0.3487590291113947), (0.36696809539811914, 0.3487590291113947)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 6, 'Type': 6, 'Coordinates': [(0.37357885461503637, 0.34753687194524197), (0.37357885461503637, 0.34753687194524197)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 7, 'Type': 6, 'Coordinates': [(0.3743010383950357, 0.3469257933621656), (0.3743010383950357, 0.3469257933621656)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 8, 'Type': 6, 'Coordinates': [(0.37496766957657357, 0.3478146349375494), (0.37496766957657357, 0.3478146349375494)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 9, 'Type': 6, 'Coordinates': [(0.3833005593457969, 0.34453703162832156), (0.3833005593457969, 0.34453703162832156)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 10, 'Type': 6, 'Coordinates': [(0.3839671905273348, 0.3453703206052439), (0.3839671905273348, 0.3453703206052439)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 11, 'Type': 6, 'Coordinates': [(0.38663371525348633, 0.3366485626467901), (0.38663371525348633, 0.3366485626467901)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 12, 'Type': 6, 'Coordinates': [(0.3825783755657976, 0.3380373776083273), (0.3825783755657976, 0.3380373776083273)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 13, 'Type': 6, 'Coordinates': [(0.3593018368104337, 0.35709191888061803), (0.3593018368104337, 0.35709191888061803)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 14, 'Type': 6, 'Coordinates': [(0.360579546575048, 0.35898070722830866), (0.360579546575048, 0.35898070722830866)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 15, 'Type': 6, 'Coordinates': [(0.35985736279504854, 0.3579252078575404), (0.35985736279504854, 0.3579252078575404)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 16, 'Type': 6, 'Coordinates': [(0.35846854783351134, 0.35925847022061613), (0.35846854783351134, 0.35925847022061613)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 17, 'Type': 6, 'Coordinates': [(0.36041288877966343, 0.36014731179599996), (0.36041288877966343, 0.36014731179599996)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 18, 'Type': 6, 'Coordinates': [(0.3628016505135075, 0.3629249417190744), (0.3628016505135075, 0.3629249417190744)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 19, 'Type': 6, 'Coordinates': [(0.3636904920888913, 0.36248052093138255), (0.3636904920888913, 0.36248052093138255)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 20, 'Type': 6, 'Coordinates': [(0.3636904920888913, 0.3633693625067663), (0.3636904920888913, 0.3633693625067663)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 21, 'Type': 6, 'Coordinates': [(0.3538576821612078, 0.3550920253360045), (0.3538576821612078, 0.3550920253360045)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 22, 'Type': 6, 'Coordinates': [(0.312193233315091, 0.33942619256986456), (0.312193233315091, 0.33942619256986456)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 23, 'Type': 6, 'Coordinates': [(0.3141375742612431, 0.34014837634986395), (0.3141375742612431, 0.34014837634986395)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 24, 'Type': 6, 'Coordinates': [(0.3087489722104787, 0.33914842957755714), (0.3087489722104787, 0.33914842957755714)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 25, 'Type': 6, 'Coordinates': [(0.3291923284443066, 0.33087109240679524), (0.3291923284443066, 0.33087109240679524)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 26, 'Type': 6, 'Coordinates': [(0.32441480497661856, 0.3603695221898459), (0.32441480497661856, 0.3603695221898459)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 27, 'Type': 6, 'Coordinates': [(0.3167485463889331, 0.3625916261283055), (0.3167485463889331, 0.3625916261283055)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 28, 'Type': 6, 'Coordinates': [(0.3491357112919812, 0.3725910938513735), (0.3491357112919812, 0.3725910938513735)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 29, 'Type': 6, 'Coordinates': [(0.38702258344271667, 0.36025841699292294), (0.38702258344271667, 0.36025841699292294)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 30, 'Type': 6, 'Coordinates': [(0.3833005593457969, 0.3635915729006122), (0.3833005593457969, 0.3635915729006122)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 31, 'Type': 6, 'Coordinates': [(0.3878003198211775, 0.36503594046061105), (0.3878003198211775, 0.36503594046061105)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 32, 'Type': 6, 'Coordinates': [(0.39791089274116853, 0.3544809467529281), (0.39791089274116853, 0.3544809467529281)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 33, 'Type': 6, 'Coordinates': [(0.3561908912965903, 0.3405927971375558), (0.3561908912965903, 0.3405927971375558)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 34, 'Type': 6, 'Coordinates': [(0.36002402059043304, 0.3469257933621656), (0.36002402059043304, 0.3469257933621656)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 35, 'Type': 6, 'Coordinates': [(0.35724639066735864, 0.35231439541293), (0.35724639066735864, 0.35231439541293)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 36, 'Type': 6, 'Coordinates': [(0.33446982529814806, 0.33748185162371247), (0.33446982529814806, 0.33748185162371247)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 37, 'Type': 6, 'Coordinates': [(0.33169219537507366, 0.3228715182283408), (0.33169219537507366, 0.3228715182283408)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 38, 'Type': 6, 'Coordinates': [(0.3496912372765961, 0.3229270708268024), (0.3496912372765961, 0.3229270708268024)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 39, 'Type': 6, 'Coordinates': [(0.32163717505354417, 0.3609806007729223), (0.32163717505354417, 0.3609806007729223)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 40, 'Type': 6, 'Coordinates': [(0.32624804072584773, 0.3667580710129172), (0.32624804072584773, 0.3667580710129172)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 41, 'Type': 6, 'Coordinates': [(0.3402472955381429, 0.36803578077753146), (0.3402472955381429, 0.36803578077753146)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 42, 'Type': 6, 'Coordinates': [(0.33774742860737594, 0.36764691258830096), (0.33774742860737594, 0.36764691258830096)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 43, 'Type': 6, 'Coordinates': [(0.3865226100565633, 0.370035674322145), (0.3865226100565633, 0.370035674322145)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 44, 'Type': 6, 'Coordinates': [(0.26823070503919905, 0.34930334948437797), (0.26823070503919905, 0.34930334948437797)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 45, 'Type': 6, 'Coordinates': [(0.26761962645612264, 0.3422481694797689), (0.26761962645612264, 0.3422481694797689)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 46, 'Type': 6, 'Coordinates': [(0.26012002566382164, 0.35185876901360646), (0.26012002566382164, 0.35185876901360646)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 47, 'Type': 6, 'Coordinates': [(0.2756747532330385, 0.35474750413360384), (0.2756747532330385, 0.35474750413360384)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 48, 'Type': 6, 'Coordinates': [(0.27234159732534924, 0.35880284382129257), (0.27234159732534924, 0.35880284382129257)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 49, 'Type': 6, 'Coordinates': [(0.2648419965330482, 0.3360262784520821), (0.2648419965330482, 0.3360262784520821)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 50, 'Type': 6, 'Coordinates': [(0.26195326141305075, 0.33263756994593124), (0.26195326141305075, 0.33263756994593124)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 51, 'Type': 6, 'Coordinates': [(0.26623081149458544, 0.3258046003351681), (0.26623081149458544, 0.3258046003351681)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 52, 'Type': 6, 'Coordinates': [(0.2598422626715142, 0.318860525527482), (0.2598422626715142, 0.318860525527482)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 53, 'Type': 6, 'Coordinates': [(0.2649531017299712, 0.31819389434594414), (0.2649531017299712, 0.31819389434594414)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 54, 'Type': 6, 'Coordinates': [(0.16929234491353645, 0.31520104032380614), (0.16929234491353645, 0.31520104032380614)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 55, 'Type': 6, 'Coordinates': [(0.1724588430258413, 0.3139788831576534), (0.1724588430258413, 0.3139788831576534)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 56, 'Type': 6, 'Coordinates': [(0.16473703183969435, 0.30631262456996794), (0.16473703183969435, 0.30631262456996794)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 57, 'Type': 6, 'Coordinates': [(0.1635148746735416, 0.3193674852084178), (0.1635148746735416, 0.3193674852084178)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 58, 'Type': 6, 'Coordinates': [(0.1719588696396879, 0.32136737875303145), (0.1719588696396879, 0.32136737875303145)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 59, 'Type': 6, 'Coordinates': [(0.16925491046174782, 0.2850534362077585), (0.16925491046174782, 0.2850534362077585)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 60, 'Type': 6, 'Coordinates': [(0.16414407140329082, 0.29860827023236186), (0.16414407140329082, 0.29860827023236186)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 61, 'Type': 6, 'Coordinates': [(0.24447985161823876, 0.2624838723500566), (0.24447985161823876, 0.2624838723500566)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 62, 'Type': 6, 'Coordinates': [(0.23959122295362772, 0.2650392918792851), (0.23959122295362772, 0.2650392918792851)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 63, 'Type': 6, 'Coordinates': [(0.23948011775670475, 0.2685946581808204), (0.23948011775670475, 0.2685946581808204)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 64, 'Type': 6, 'Coordinates': [(0.23998009114285815, 0.26070618919928895), (0.23998009114285815, 0.26070618919928895)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 65, 'Type': 6, 'Coordinates': [(0.23442483129670927, 0.2584285326623679), (0.23442483129670927, 0.2584285326623679)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 66, 'Type': 6, 'Coordinates': [(0.20992613537519259, 0.24370709407007332), (0.20992613537519259, 0.24370709407007332)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 67, 'Type': 6, 'Coordinates': [(0.21409258025980427, 0.2422627265100746), (0.21409258025980427, 0.2422627265100746)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 68, 'Type': 6, 'Coordinates': [(0.2164257893951868, 0.240262832965461), (0.2164257893951868, 0.240262832965461)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 69, 'Type': 6, 'Coordinates': [(0.207926241830579, 0.23831849201930888), (0.207926241830579, 0.23831849201930888)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 70, 'Type': 6, 'Coordinates': [(0.23470259428901669, 0.2367074666639257), (0.23470259428901669, 0.2367074666639257)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 71, 'Type': 6, 'Coordinates': [(0.21496879023250362, 0.23168239492142492), (0.21496879023250362, 0.23168239492142492)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 72, 'Type': 6, 'Coordinates': [(0.21769086755711659, 0.2311268689368101), (0.21769086755711659, 0.2311268689368101)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 73, 'Type': 6, 'Coordinates': [(0.21902412992019232, 0.23034913255834918), (0.21902412992019232, 0.23034913255834918)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 74, 'Type': 6, 'Coordinates': [(0.21946855070788424, 0.2294602909829654), (0.21946855070788424, 0.2294602909829654)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 75, 'Type': 6, 'Coordinates': [(0.23707872442017625, 0.2218495849937414), (0.23707872442017625, 0.2218495849937414)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 76, 'Type': 6, 'Coordinates': [(0.2449671934017077, 0.223960583735278), (0.2449671934017077, 0.223960583735278)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 77, 'Type': 6, 'Coordinates': [(0.24302285245555555, 0.2311268689368101), (0.24302285245555555, 0.2311268689368101)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 78, 'Type': 6, 'Coordinates': [(0.23357891071710243, 0.2380709437444962), (0.23357891071710243, 0.2380709437444962)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 79, 'Type': 6, 'Coordinates': [(0.24557827198478405, 0.21418332640605592), (0.24557827198478405, 0.21418332640605592)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 80, 'Type': 6, 'Coordinates': [(0.2510779792324715, 0.21112793349067402), (0.2510779792324715, 0.21112793349067402)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 81, 'Type': 6, 'Coordinates': [(0.2538556091555459, 0.21168345947528894), (0.2538556091555459, 0.21168345947528894)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 82, 'Type': 6, 'Coordinates': [(0.2605774735693861, 0.2218495849937414), (0.2605774735693861, 0.2218495849937414)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 83, 'Type': 6, 'Coordinates': [(0.2665771542032269, 0.2130722744368261), (0.2665771542032269, 0.2130722744368261)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 84, 'Type': 6, 'Coordinates': [(0.2645772606586133, 0.2117390120737504), (0.2645772606586133, 0.2117390120737504)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 85, 'Type': 6, 'Coordinates': [(0.26207739372784633, 0.1940732857629969), (0.26207739372784633, 0.1940732857629969)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 86, 'Type': 6, 'Coordinates': [(0.25413337214785336, 0.2030728067137581), (0.25413337214785336, 0.2030728067137581)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 87, 'Type': 6, 'Coordinates': [(0.2588553430170799, 0.2072392515983698), (0.2588553430170799, 0.2072392515983698)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 88, 'Type': 6, 'Coordinates': [(0.2801319882278302, 0.20501714765991022), (0.2801319882278302, 0.20501714765991022)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 89, 'Type': 6, 'Coordinates': [(0.2756877803509111, 0.2025172807291432), (0.2756877803509111, 0.2025172807291432)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 90, 'Type': 6, 'Coordinates': [(0.2701325205047622, 0.20212841253991282), (0.2701325205047622, 0.20212841253991282)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 91, 'Type': 6, 'Coordinates': [(0.27946535704629233, 0.19518433773222668), (0.27946535704629233, 0.19518433773222668)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 92, 'Type': 6, 'Coordinates': [(0.2812985927955215, 0.19696202088299433), (0.2812985927955215, 0.19696202088299433)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 93, 'Type': 6, 'Coordinates': [(0.2784654102739855, 0.2250160831060463), (0.2784654102739855, 0.2250160831060463)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 94, 'Type': 6, 'Coordinates': [(0.2792986992509079, 0.23168239492142492), (0.2792986992509079, 0.23168239492142492)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 95, 'Type': 6, 'Coordinates': [(0.28263185515859723, 0.2227939791675867), (0.28263185515859723, 0.2227939791675867)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 96, 'Type': 6, 'Coordinates': [(0.2874093786262853, 0.22346061034912457), (0.2874093786262853, 0.22346061034912457)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 97, 'Type': 6, 'Coordinates': [(0.29324240146474156, 0.22268287397066372), (0.29324240146474156, 0.22268287397066372)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 98, 'Type': 6, 'Coordinates': [(0.2814096979924444, 0.23657102358603596), (0.2814096979924444, 0.23657102358603596)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 99, 'Type': 6, 'Coordinates': [(0.2798542252355227, 0.23673768138142046), (0.2798542252355227, 0.23673768138142046)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 100, 'Type': 6, 'Coordinates': [(0.31227712368105287, 0.18347325417370933), (0.31227712368105287, 0.18347325417370933)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 101, 'Type': 6, 'Coordinates': [(0.31027723013643926, 0.18230664960601803), (0.31027723013643926, 0.18230664960601803)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 102, 'Type': 6, 'Coordinates': [(0.30766625800874925, 0.1825844125983255), (0.30766625800874925, 0.1825844125983255)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 103, 'Type': 6, 'Coordinates': [(0.3080551261979797, 0.18502872693063102), (0.3080551261979797, 0.18502872693063102)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 104, 'Type': 6, 'Coordinates': [(0.2972223694979893, 0.17597365338140827), (0.2972223694979893, 0.17597365338140827)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 105, 'Type': 6, 'Coordinates': [(0.3440532100010245, 0.15975229463065352), (0.3440532100010245, 0.15975229463065352)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 106, 'Type': 6, 'Coordinates': [(0.3389979235410291, 0.16075224140296032), (0.3389979235410291, 0.16075224140296032)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 107, 'Type': 6, 'Coordinates': [(0.3400534229117973, 0.15697466470757906), (0.3400534229117973, 0.15697466470757906)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 108, 'Type': 6, 'Coordinates': [(0.35255275756563237, 0.15058611588450782), (0.35255275756563237, 0.15058611588450782)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 109, 'Type': 6, 'Coordinates': [(0.35760804402562785, 0.14903064312758615), (0.35760804402562785, 0.14903064312758615)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 110, 'Type': 6, 'Coordinates': [(0.36277443568254636, 0.15119719446758423), (0.36277443568254636, 0.15119719446758423)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 111, 'Type': 6, 'Coordinates': [(0.35666364985178256, 0.172418287079873), (0.35666364985178256, 0.172418287079873)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 112, 'Type': 6, 'Coordinates': [(0.35805246481331976, 0.1728627078675649), (0.35805246481331976, 0.1728627078675649)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 113, 'Type': 6, 'Coordinates': [(0.3597190427671645, 0.17180720849679662), (0.3597190427671645, 0.17180720849679662)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 114, 'Type': 6, 'Coordinates': [(0.36566317080254374, 0.1691962363691066), (0.36566317080254374, 0.1691962363691066)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 115, 'Type': 6, 'Coordinates': [(0.359619581394879, 0.14978998048543649), (0.359619581394879, 0.14978998048543649)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 116, 'Type': 6, 'Coordinates': [(0.372007810851791, 0.14795674473620737), (0.372007810851791, 0.14795674473620737)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 117, 'Type': 6, 'Coordinates': [(0.3711189692764072, 0.13934609197467657), (0.3711189692764072, 0.13934609197467657)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 118, 'Type': 6, 'Coordinates': [(0.37672978172101756, 0.14306811607159634), (0.37672978172101756, 0.14306811607159634)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 119, 'Type': 6, 'Coordinates': [(0.3726744420333289, 0.14695679796390057), (0.3726744420333289, 0.14695679796390057)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 120, 'Type': 6, 'Coordinates': [(0.36267497431026086, 0.16728904900080555), (0.36267497431026086, 0.16728904900080555)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 121, 'Type': 6, 'Coordinates': [(0.37812911057965115, 0.2035210703061831), (0.37812911057965115, 0.2035210703061831)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 122, 'Type': 6, 'Coordinates': [(0.37718471640580586, 0.2018544923523384), (0.37718471640580586, 0.2018544923523384)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 123, 'Type': 6, 'Coordinates': [(0.3741848760888855, 0.19868799424003356), (0.3741848760888855, 0.19868799424003356)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 124, 'Type': 6, 'Coordinates': [(0.3939616011411755, 0.2110206710984841), (0.3939616011411755, 0.2110206710984841)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 125, 'Type': 6, 'Coordinates': [(0.40801640855193233, 0.21296501204463622), (0.40801640855193233, 0.21296501204463622)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 126, 'Type': 6, 'Coordinates': [(0.40690535658270244, 0.214076064013866), (0.40690535658270244, 0.214076064013866)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 127, 'Type': 6, 'Coordinates': [(0.4134605632011582, 0.2066320158200265), (0.4134605632011582, 0.2066320158200265)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 128, 'Type': 6, 'Coordinates': [(0.4234600309242261, 0.21146509188617602), (0.4234600309242261, 0.21146509188617602)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 129, 'Type': 6, 'Coordinates': [(0.40707201437808704, 0.23307505268769524), (0.40707201437808704, 0.23307505268769524)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 130, 'Type': 6, 'Coordinates': [(0.417182587298078, 0.22640874087231658), (0.417182587298078, 0.22640874087231658)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 131, 'Type': 6, 'Coordinates': [(0.4187380600549996, 0.2292419233938525), (0.4187380600549996, 0.2292419233938525)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 132, 'Type': 6, 'Coordinates': [(0.41790477107807733, 0.23668597158769203), (0.41790477107807733, 0.23668597158769203)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 133, 'Type': 6, 'Coordinates': [(0.4271820550211459, 0.21479824779386533), (0.4271820550211459, 0.21479824779386533)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 134, 'Type': 6, 'Coordinates': [(0.4088496975288546, 0.21752032511847835), (0.4088496975288546, 0.21752032511847835)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 135, 'Type': 6, 'Coordinates': [(0.3972947570488649, 0.20629870022925756), (0.3972947570488649, 0.20629870022925756)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 136, 'Type': 6, 'Coordinates': [(0.4352371817980618, 0.22963079158308292), (0.4352371817980618, 0.22963079158308292)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 137, 'Type': 6, 'Coordinates': [(0.44495888652882243, 0.23135292213538905), (0.44495888652882243, 0.23135292213538905)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 138, 'Type': 6, 'Coordinates': [(0.44568107030882176, 0.23757481316307585), (0.44568107030882176, 0.23757481316307585)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 139, 'Type': 6, 'Coordinates': [(0.43612602337344575, 0.2387969703292286), (0.43612602337344575, 0.2387969703292286)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 140, 'Type': 6, 'Coordinates': [(0.43612602337344575, 0.2362971033984616), (0.43612602337344575, 0.2362971033984616)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 141, 'Type': 6, 'Coordinates': [(0.4311262895119117, 0.24113017946461116), (0.4311262895119117, 0.24113017946461116)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 142, 'Type': 6, 'Coordinates': [(0.43507052400267743, 0.24168570544922602), (0.43507052400267743, 0.24168570544922602)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 143, 'Type': 6, 'Coordinates': [(0.42634876604422356, 0.2397413645030739), (0.42634876604422356, 0.2397413645030739)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 144, 'Type': 6, 'Coordinates': [(0.4252377140749939, 0.2438522567892241), (0.4252377140749939, 0.2438522567892241)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 145, 'Type': 6, 'Coordinates': [(0.35635249198274754, 0.24090796907076517), (0.35635249198274754, 0.24090796907076517)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 146, 'Type': 6, 'Coordinates': [(0.36501869734273973, 0.23607489300461565), (0.36501869734273973, 0.23607489300461565)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 147, 'Type': 6, 'Coordinates': [(0.38723973672733536, 0.2171314569292479), (0.38723973672733536, 0.2171314569292479)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 148, 'Type': 6, 'Coordinates': [(0.3669630382888919, 0.24251899442614833), (0.3669630382888919, 0.24251899442614833)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 149, 'Type': 6, 'Coordinates': [(0.3856831085873963, 0.17959745437042302), (0.3856831085873963, 0.17959745437042302)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 150, 'Type': 6, 'Coordinates': [(0.38346100464893673, 0.18481939862580296), (0.38346100464893673, 0.18481939862580296)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 151, 'Type': 6, 'Coordinates': [(0.374405931099714, 0.18648597657964763), (0.374405931099714, 0.18648597657964763)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 152, 'Type': 6, 'Coordinates': [(0.3688506712535651, 0.18898584351041464), (0.3688506712535651, 0.18898584351041464)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 153, 'Type': 6, 'Coordinates': [(0.3757947460612512, 0.1831528206719583), (0.3757947460612512, 0.1831528206719583)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 154, 'Type': 6, 'Coordinates': [(0.3737392999181761, 0.17970855956734597), (0.3737392999181761, 0.17970855956734597)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 155, 'Type': 6, 'Coordinates': [(0.3909606054412378, 0.18943026429810653), (0.3909606054412378, 0.18943026429810653)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 156, 'Type': 6, 'Coordinates': [(0.3831832416566293, 0.187097055162724), (0.3831832416566293, 0.187097055162724)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 157, 'Type': 6, 'Coordinates': [(0.3988490744227692, 0.20248512493655646), (0.3988490744227692, 0.20248512493655646)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 158, 'Type': 6, 'Coordinates': [(0.2395260641794832, 0.4575401110602763), (0.2395260641794832, 0.4575401110602763)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 159, 'Type': 6, 'Coordinates': [(0.23424856732564175, 0.4578178740525838), (0.23424856732564175, 0.4578178740525838)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 160, 'Type': 6, 'Coordinates': [(0.24319253567794144, 0.45504024412950933), (0.24319253567794144, 0.45504024412950933)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 161, 'Type': 6, 'Coordinates': [(0.2586917106486969, 0.4577067688556608), (0.2586917106486969, 0.4577067688556608)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 162, 'Type': 6, 'Coordinates': [(0.2440813772533253, 0.46559523783719226), (0.2440813772533253, 0.46559523783719226)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 163, 'Type': 6, 'Coordinates': [(0.20425016415643768, 0.4593733468095055), (0.20425016415643768, 0.4593733468095055)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 164, 'Type': 6, 'Coordinates': [(0.20686113628412767, 0.4694839197294965), (0.20686113628412767, 0.4694839197294965)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 165, 'Type': 6, 'Coordinates': [(0.25208095143177967, 0.4600955305895048), (0.25208095143177967, 0.4600955305895048)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 166, 'Type': 6, 'Coordinates': [(0.23830390701333043, 0.4572623480679689), (0.23830390701333043, 0.4572623480679689)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 167, 'Type': 6, 'Coordinates': [(0.23735951283948512, 0.45604019090181613), (0.23735951283948512, 0.45604019090181613)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 168, 'Type': 6, 'Coordinates': [(0.2404704583533285, 0.4562624012956621), (0.2404704583533285, 0.4562624012956621)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 169, 'Type': 6, 'Coordinates': [(0.2435258512687104, 0.4525403771987423), (0.2435258512687104, 0.4525403771987423)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 170, 'Type': 6, 'Coordinates': [(0.255414107339469, 0.433985809312605), (0.255414107339469, 0.433985809312605)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 171, 'Type': 6, 'Coordinates': [(0.2359151452794864, 0.44059656852952217), (0.2359151452794864, 0.44059656852952217)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 172, 'Type': 6, 'Coordinates': [(0.2789684090871404, 0.431597047578761), (0.2789684090871404, 0.431597047578761)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 173, 'Type': 6, 'Coordinates': [(0.2479577575782261, 0.42463048507921713), (0.2479577575782261, 0.42463048507921713)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 174, 'Type': 6, 'Coordinates': [(0.27501187302897123, 0.4289635877592133), (0.27501187302897123, 0.4289635877592133)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 175, 'Type': 6, 'Coordinates': [(0.27778950295204574, 0.4292413507515207), (0.27778950295204574, 0.4292413507515207)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 176, 'Type': 6, 'Coordinates': [(0.278956107519737, 0.42813029878229103), (0.278956107519737, 0.42813029878229103)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 177, 'Type': 6, 'Coordinates': [(0.28295589460896414, 0.4281858513807525), (0.28295589460896414, 0.4281858513807525)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 178, 'Type': 6, 'Coordinates': [(0.2832336576012716, 0.43007463972844306), (0.2832336576012716, 0.43007463972844306)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 179, 'Type': 6, 'Coordinates': [(0.28934444343203536, 0.4349077157945927), (0.28934444343203536, 0.4349077157945927)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 180, 'Type': 6, 'Coordinates': [(0.293955309104339, 0.43035240272075054), (0.293955309104339, 0.43035240272075054)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 181, 'Type': 6, 'Coordinates': [(0.3011215943058711, 0.4316301124853648), (0.3011215943058711, 0.4316301124853648)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 182, 'Type': 6, 'Coordinates': [(0.3108988516350931, 0.43040795531921205), (0.3108988516350931, 0.43040795531921205)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 183, 'Type': 6, 'Coordinates': [(0.3130654029750912, 0.43263005925767156), (0.3130654029750912, 0.43263005925767156)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 184, 'Type': 6, 'Coordinates': [(0.314176454944321, 0.42324167011768), (0.314176454944321, 0.42324167011768)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 185, 'Type': 6, 'Coordinates': [(0.30545469698586725, 0.4160753849161479), (0.30545469698586725, 0.4160753849161479)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 186, 'Type': 6, 'Coordinates': [(0.283955841381271, 0.42385274870075634), (0.283955841381271, 0.42385274870075634)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 187, 'Type': 6, 'Coordinates': [(0.34371621586062706, 0.4171389194147578), (0.34371621586062706, 0.4171389194147578)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 188, 'Type': 6, 'Coordinates': [(0.3383831664083241, 0.4123058433486082), (0.3383831664083241, 0.4123058433486082)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 189, 'Type': 6, 'Coordinates': [(0.33693879884832545, 0.4180277609901416), (0.33693879884832545, 0.4180277609901416)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 190, 'Type': 6, 'Coordinates': [(0.33366119553909757, 0.4248051780024433), (0.33366119553909757, 0.4248051780024433)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 191, 'Type': 6, 'Coordinates': [(0.3366610358560179, 0.42191644288244584), (0.3366610358560179, 0.42191644288244584)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 192, 'Type': 6, 'Coordinates': [(0.33971642877139985, 0.42769391312244065), (0.33971642877139985, 0.42769391312244065)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 193, 'Type': 6, 'Coordinates': [(0.33893869239293906, 0.4249162831993662), (0.33893869239293906, 0.4249162831993662)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 194, 'Type': 6, 'Coordinates': [(0.33971642877139985, 0.4223053110716763), (0.33971642877139985, 0.4223053110716763)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 195, 'Type': 6, 'Coordinates': [(0.3101068937914262, 0.4018619548378483), (0.3101068937914262, 0.4018619548378483)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 196, 'Type': 6, 'Coordinates': [(0.3246061219898749, 0.4007509028686186), (0.3246061219898749, 0.4007509028686186)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 197, 'Type': 6, 'Coordinates': [(0.32738375191294933, 0.4031396646024626), (0.32738375191294933, 0.4031396646024626)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 198, 'Type': 6, 'Coordinates': [(0.3244394641944904, 0.4069727938963053), (0.3244394641944904, 0.4069727938963053)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 199, 'Type': 6, 'Coordinates': [(0.29083014212528957, 0.4232497052455215), (0.29083014212528957, 0.4232497052455215)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 200, 'Type': 6, 'Coordinates': [(0.3322168279790989, 0.40858381925168846), (0.3322168279790989, 0.40858381925168846)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 201, 'Type': 6, 'Coordinates': [(0.3702837175233606, 0.25842611185261705), (0.3702837175233606, 0.25842611185261705)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 202, 'Type': 6, 'Coordinates': [(0.3708596868642093, 0.25543107128020376), (0.3708596868642093, 0.25543107128020376)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 203, 'Type': 6, 'Coordinates': [(0.3558844840021426, 0.25543107128020376), (0.3558844840021426, 0.25543107128020376)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 204, 'Type': 6, 'Coordinates': [(0.34724494388941185, 0.2531271939168089), (0.34724494388941185, 0.2531271939168089)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 205, 'Type': 6, 'Coordinates': [(0.42115060985189845, 0.2621685793057709), (0.42115060985189845, 0.2621685793057709)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 206, 'Type': 6, 'Coordinates': [(0.3836526058903933, 0.2577243714288518), (0.3836526058903933, 0.2577243714288518)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 207, 'Type': 6, 'Coordinates': [(0.423039398199589, 0.26605726119807516), (0.423039398199589, 0.26605726119807516)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 208, 'Type': 6, 'Coordinates': [(0.4082068544103715, 0.25583558308116117), (0.4082068544103715, 0.25583558308116117)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 209, 'Type': 6, 'Coordinates': [(0.38481921045808465, 0.25244687457501036), (0.38481921045808465, 0.25244687457501036)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 210, 'Type': 6, 'Coordinates': [(0.390652233296541, 0.248891508273475), (0.390652233296541, 0.248891508273475)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 211, 'Type': 6, 'Coordinates': [(0.35865393658272327, 0.24928037646270548), (0.35865393658272327, 0.24928037646270548)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 212, 'Type': 6, 'Coordinates': [(0.3537653079181122, 0.2510580596134731), (0.3537653079181122, 0.2510580596134731)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 213, 'Type': 6, 'Coordinates': [(0.35126544098734525, 0.25466897851346987), (0.35126544098734525, 0.25466897851346987)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 214, 'Type': 6, 'Coordinates': [(0.3614315665057978, 0.26189081631346345), (0.3614315665057978, 0.26189081631346345)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 215, 'Type': 6, 'Coordinates': [(0.35498746508426504, 0.28622285443959566), (0.35498746508426504, 0.28622285443959566)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 216, 'Type': 6, 'Coordinates': [(0.35404307091041975, 0.2891115895595931), (0.35404307091041975, 0.2891115895595931)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 217, 'Type': 6, 'Coordinates': [(0.35554299106887993, 0.2888338265672856), (0.35554299106887993, 0.2888338265672856)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 218, 'Type': 6, 'Coordinates': [(0.35282091374426694, 0.294666849405742), (0.35282091374426694, 0.294666849405742)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 219, 'Type': 6, 'Coordinates': [(0.36443140682271813, 0.29033374672574586), (0.36443140682271813, 0.29033374672574586)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 220, 'Type': 6, 'Coordinates': [(0.36532024839810195, 0.28522290766728886), (0.36532024839810195, 0.28522290766728886)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 221, 'Type': 6, 'Coordinates': [(0.3655424587919479, 0.297166716336509), (0.3655424587919479, 0.297166716336509)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 222, 'Type': 6, 'Coordinates': [(0.36704237895040814, 0.29694450594266303), (0.36704237895040814, 0.29694450594266303)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 223, 'Type': 6, 'Coordinates': [(0.4033182257457605, 0.2855006706595963), (0.4033182257457605, 0.2855006706595963)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 224, 'Type': 6, 'Coordinates': [(0.39720743991499663, 0.28305635632729076), (0.39720743991499663, 0.28305635632729076)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 225, 'Type': 6, 'Coordinates': [(0.38587470982885286, 0.24761379850886076), (0.38587470982885286, 0.24761379850886076)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 226, 'Type': 6, 'Coordinates': [(0.36859785170732984, 0.25894652859500455), (0.36859785170732984, 0.25894652859500455)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 227, 'Type': 6, 'Coordinates': [(0.3588761469765692, 0.25428011032423947), (0.3588761469765692, 0.25428011032423947)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 228, 'Type': 6, 'Coordinates': [(0.4223172144195897, 0.2738346249826836), (0.4223172144195897, 0.2738346249826836)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 229, 'Type': 6, 'Coordinates': [(0.42609479111497095, 0.2725013626196079), (0.42609479111497095, 0.2725013626196079)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 230, 'Type': 6, 'Coordinates': [(0.4244282131611262, 0.2706681268703787), (0.4244282131611262, 0.2706681268703787)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 231, 'Type': 6, 'Coordinates': [(0.407929091418064, 0.29438908641343453), (0.407929091418064, 0.29438908641343453)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 232, 'Type': 6, 'Coordinates': [(0.3859858150257759, 0.2863895122349801), (0.3859858150257759, 0.2863895122349801)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 233, 'Type': 6, 'Coordinates': [(0.4402607037226507, 0.27466791395960594), (0.4402607037226507, 0.27466791395960594)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 234, 'Type': 6, 'Coordinates': [(0.4425383602595716, 0.2763344919134506), (0.4425383602595716, 0.2763344919134506)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 235, 'Type': 6, 'Coordinates': [(0.43426102308880976, 0.27055702167345574), (0.43426102308880976, 0.27055702167345574)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 236, 'Type': 6, 'Coordinates': [(0.43581649584573146, 0.2656683930088447), (0.43581649584573146, 0.2656683930088447)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 237, 'Type': 6, 'Coordinates': [(0.4349832068688092, 0.2647239988349994), (0.4349832068688092, 0.2647239988349994)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 238, 'Type': 6, 'Coordinates': [(0.42998347300727513, 0.25777992402731326), (0.42998347300727513, 0.25777992402731326)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 239, 'Type': 6, 'Coordinates': [(0.418150769534978, 0.26177971111654047), (0.418150769534978, 0.26177971111654047)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 240, 'Type': 6, 'Coordinates': [(0.43431657568727133, 0.28861161617343967), (0.43431657568727133, 0.28861161617343967)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 241, 'Type': 6, 'Coordinates': [(0.36379647173175844, 0.24698549417605342), (0.36379647173175844, 0.24698549417605342)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 242, 'Type': 6, 'Coordinates': [(0.35963002684714673, 0.24576333700990066), (0.35963002684714673, 0.24576333700990066)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 243, 'Type': 6, 'Coordinates': [(0.38951732481942786, 0.26648445623603606), (0.38951732481942786, 0.26648445623603606)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 244, 'Type': 6, 'Coordinates': [(0.4085163134932571, 0.2685399023791112), (0.4085163134932571, 0.2685399023791112)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 245, 'Type': 6, 'Coordinates': [(0.4137938103470985, 0.25954038142834995), (0.4137938103470985, 0.25954038142834995)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 246, 'Type': 6, 'Coordinates': [(0.35713015991637975, 0.26481787828219144), (0.35713015991637975, 0.26481787828219144)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 247, 'Type': 6, 'Coordinates': [(0.380906672057897, 0.27115087450680114), (0.380906672057897, 0.27115087450680114)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 248, 'Type': 6, 'Coordinates': [(0.3426864843163926, 0.2436523382683641), (0.3426864843163926, 0.2436523382683641)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 249, 'Type': 6, 'Coordinates': [(0.371129414728675, 0.2357083166883712), (0.371129414728675, 0.2357083166883712)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 250, 'Type': 6, 'Coordinates': [(0.37135162512252096, 0.23437505432529546), (0.37135162512252096, 0.23437505432529546)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 251, 'Type': 6, 'Coordinates': [(0.322854206665641, 0.26576227245603673), (0.322854206665641, 0.26576227245603673)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 252, 'Type': 6, 'Coordinates': [(0.32802059832255953, 0.24187465511759648), (0.32802059832255953, 0.24187465511759648)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 253, 'Type': 6, 'Coordinates': [(0.3285205717087129, 0.23770821023298477), (0.3285205717087129, 0.23770821023298477)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 254, 'Type': 6, 'Coordinates': [(0.29107243972360797, 0.21899860621905795), (0.29107243972360797, 0.21899860621905795)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 255, 'Type': 6, 'Coordinates': [(0.3043359814689841, 0.23196757276302987), (0.3043359814689841, 0.23196757276302987)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 256, 'Type': 6, 'Coordinates': [(0.2967808280782216, 0.23102317858918459), (0.2967808280782216, 0.23102317858918459)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 257, 'Type': 6, 'Coordinates': [(0.3068358483997511, 0.23963383135071537), (0.3068358483997511, 0.23963383135071537)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 258, 'Type': 6, 'Coordinates': [(0.3182241310843563, 0.2369673066245639), (0.3182241310843563, 0.2369673066245639)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 259, 'Type': 6, 'Coordinates': [(0.28739243893822997, 0.24346696064455814), (0.28739243893822997, 0.24346696064455814)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 260, 'Type': 6, 'Coordinates': [(0.2901700688613044, 0.23985604174456132), (0.2901700688613044, 0.23985604174456132)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 261, 'Type': 6, 'Coordinates': [(0.2962253020936067, 0.2409115411153296), (0.2962253020936067, 0.2409115411153296)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 262, 'Type': 6, 'Coordinates': [(0.28128165310746617, 0.23924496316148497), (0.28128165310746617, 0.23924496316148497)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 263, 'Type': 6, 'Coordinates': [(0.2948364871320695, 0.20713556125074428), (0.2948364871320695, 0.20713556125074428)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 264, 'Type': 6, 'Coordinates': [(0.2956697761089918, 0.2007470124276731), (0.2956697761089918, 0.2007470124276731)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 265, 'Type': 6, 'Coordinates': [(0.27850013005829133, 0.26909830383022), (0.27850013005829133, 0.26909830383022)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 266, 'Type': 6, 'Coordinates': [(0.2879440717967445, 0.26387635957484), (0.2879440717967445, 0.26387635957484)], 'Color': '#00ffff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 267, 'Type': 6, 'Coordinates': [(0.2884440451828979, 0.26054320366715067), (0.2884440451828979, 0.26054320366715067)], 'Color': '#00ffff', 'Fixed Value': 1}
# ...
# {'Active': 1, 'Index': 1832, 'Type': 6, 'Coordinates': [(0.440561378561224, 0.18070509993571515), (0.440561378561224, 0.18070509993571515)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1833, 'Type': 6, 'Coordinates': [(0.4417835357273767, 0.1820383622987909), (0.4417835357273767, 0.1820383622987909)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1834, 'Type': 6, 'Coordinates': [(0.43722822265353467, 0.18276054607879022), (0.43722822265353467, 0.18276054607879022)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1835, 'Type': 6, 'Coordinates': [(0.4472276903766027, 0.17942739017110088), (0.4472276903766027, 0.17942739017110088)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1836, 'Type': 6, 'Coordinates': [(0.31786509426966203, 0.13274111014934656), (0.31786509426966203, 0.13274111014934656)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1837, 'Type': 6, 'Coordinates': [(0.3168095948988938, 0.1340188199139608), (0.3168095948988938, 0.1340188199139608)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1838, 'Type': 6, 'Coordinates': [(0.3117543084388983, 0.13751863361703462), (0.3117543084388983, 0.13751863361703462)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1839, 'Type': 6, 'Coordinates': [(0.3101988356819766, 0.13929631676780227), (0.3101988356819766, 0.13929631676780227)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1840, 'Type': 6, 'Coordinates': [(0.30997662528813064, 0.1416295259031848), (0.30997662528813064, 0.1416295259031848)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1841, 'Type': 6, 'Coordinates': [(0.3110876772573604, 0.14385162984164437), (0.3110876772573604, 0.14385162984164437)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1842, 'Type': 6, 'Coordinates': [(0.310476598674284, 0.14462936622010522), (0.310476598674284, 0.14462936622010522)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1843, 'Type': 6, 'Coordinates': [(0.3070878901681332, 0.14635149677241138), (0.3070878901681332, 0.14635149677241138)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1844, 'Type': 6, 'Coordinates': [(0.3070878901681332, 0.14835139031702496), (0.3070878901681332, 0.14835139031702496)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1845, 'Type': 6, 'Coordinates': [(0.3117543084388983, 0.14801807472625603), (0.3117543084388983, 0.14801807472625603)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1846, 'Type': 6, 'Coordinates': [(0.3052546544189041, 0.14274057787241456), (0.3052546544189041, 0.14274057787241456)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1847, 'Type': 6, 'Coordinates': [(0.30403249725275133, 0.14196284149395375), (0.30403249725275133, 0.14196284149395375)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1848, 'Type': 6, 'Coordinates': [(0.3050879966235196, 0.13735197582165015), (0.3050879966235196, 0.13735197582165015)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1849, 'Type': 6, 'Coordinates': [(0.32883841085873183, 0.1716901283807472), (0.32883841085873183, 0.1716901283807472)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1850, 'Type': 6, 'Coordinates': [(0.3390600889756458, 0.1796897025592016), (0.3390600889756458, 0.1796897025592016)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1851, 'Type': 6, 'Coordinates': [(0.3404489039371831, 0.18091185972535437), (0.3404489039371831, 0.18091185972535437)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1852, 'Type': 6, 'Coordinates': [(0.3387267733848769, 0.18207846429304567), (0.3387267733848769, 0.18207846429304567)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1853, 'Type': 6, 'Coordinates': [(0.3373379584233397, 0.18318951626227542), (0.3373379584233397, 0.18318951626227542)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1854, 'Type': 6, 'Coordinates': [(0.3366157746433403, 0.18663377736688772), (0.3366157746433403, 0.18663377736688772)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1855, 'Type': 6, 'Coordinates': [(0.3348380914925727, 0.18596714618534987), (0.3348380914925727, 0.18596714618534987)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1856, 'Type': 6, 'Coordinates': [(0.3326159875541131, 0.18646711957150328), (0.3326159875541131, 0.18646711957150328)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1857, 'Type': 6, 'Coordinates': [(0.33911564157410734, 0.1884114605176554), (0.33911564157410734, 0.1884114605176554)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1858, 'Type': 6, 'Coordinates': [(0.33744906362026267, 0.18863367091150135), (0.33744906362026267, 0.18863367091150135)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1859, 'Type': 6, 'Coordinates': [(0.3359491434618024, 0.1884114605176554), (0.3359491434618024, 0.1884114605176554)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1860, 'Type': 6, 'Coordinates': [(0.3365046694464173, 0.19030024886534602), (0.3365046694464173, 0.19030024886534602)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1861, 'Type': 6, 'Coordinates': [(0.33444922330334226, 0.19163351122842173), (0.33444922330334226, 0.19163351122842173)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1862, 'Type': 6, 'Coordinates': [(0.33322706613718944, 0.19246680020534407), (0.33322706613718944, 0.19246680020534407)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1863, 'Type': 6, 'Coordinates': [(0.3318938037741137, 0.19252235280380556), (0.3318938037741137, 0.19252235280380556)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1864, 'Type': 6, 'Coordinates': [(0.3361158012571869, 0.19341119437918938), (0.3361158012571869, 0.19341119437918938)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1865, 'Type': 6, 'Coordinates': [(0.3355047226741106, 0.19230014240995963), (0.3355047226741106, 0.19230014240995963)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1866, 'Type': 6, 'Coordinates': [(0.34267100787564264, 0.1839672526407363), (0.34267100787564264, 0.1839672526407363)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1867, 'Type': 6, 'Coordinates': [(0.34100442992179797, 0.18557827799611945), (0.34100442992179797, 0.18557827799611945)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1868, 'Type': 6, 'Coordinates': [(0.33883787858179987, 0.18357838445150582), (0.33883787858179987, 0.18357838445150582)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1869, 'Type': 6, 'Coordinates': [(0.340671114331029, 0.18307841106535244), (0.340671114331029, 0.18307841106535244)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1870, 'Type': 6, 'Coordinates': [(0.34650413716948536, 0.18418946303458222), (0.34650413716948536, 0.18418946303458222)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1871, 'Type': 6, 'Coordinates': [(0.3525038178033262, 0.19135574823611431), (0.3525038178033262, 0.19135574823611431)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1872, 'Type': 6, 'Coordinates': [(0.3518371866217883, 0.1898558280776541), (0.3518371866217883, 0.1898558280776541)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1873, 'Type': 6, 'Coordinates': [(0.3493373196910212, 0.1888558813053473), (0.3493373196910212, 0.1888558813053473)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1874, 'Type': 6, 'Coordinates': [(0.34761518913871514, 0.18924474949457773), (0.34761518913871514, 0.18924474949457773)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1875, 'Type': 6, 'Coordinates': [(0.3351158544848801, 0.19968863800533765), (0.3351158544848801, 0.19968863800533765)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1876, 'Type': 6, 'Coordinates': [(0.33489364409103417, 0.2016329789514898), (0.33489364409103417, 0.2016329789514898)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1877, 'Type': 6, 'Coordinates': [(0.33522695968180305, 0.19679990288534022), (0.33522695968180305, 0.19679990288534022)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1878, 'Type': 6, 'Coordinates': [(0.3345603285002652, 0.19813316524841595), (0.3345603285002652, 0.19813316524841595)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1879, 'Type': 6, 'Coordinates': [(0.33678243243872474, 0.19746653406687809), (0.33678243243872474, 0.19746653406687809)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1880, 'Type': 6, 'Coordinates': [(0.33983782535410667, 0.1958555087114949), (0.33983782535410667, 0.1958555087114949)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1881, 'Type': 6, 'Coordinates': [(0.3430043234664115, 0.19368895737149686), (0.3430043234664115, 0.19368895737149686)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1882, 'Type': 6, 'Coordinates': [(0.3402822461417986, 0.19257790540226705), (0.3402822461417986, 0.19257790540226705)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1883, 'Type': 6, 'Coordinates': [(0.350670582054097, 0.19579995611303344), (0.350670582054097, 0.19579995611303344)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1884, 'Type': 6, 'Coordinates': [(0.34850403071409897, 0.19913311202072276), (0.34850403071409897, 0.19913311202072276)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1885, 'Type': 6, 'Coordinates': [(0.34461534882179473, 0.1983553756422619), (0.34461534882179473, 0.1983553756422619)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1886, 'Type': 6, 'Coordinates': [(0.3441709280341028, 0.20024416398995254), (0.3441709280341028, 0.20024416398995254)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1887, 'Type': 6, 'Coordinates': [(0.345670848192563, 0.2019107419437972), (0.345670848192563, 0.2019107419437972)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1888, 'Type': 6, 'Coordinates': [(0.3445597962233332, 0.20285513611764253), (0.3445597962233332, 0.20285513611764253)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1889, 'Type': 6, 'Coordinates': [(0.32428309778488973, 0.1943000359545732), (0.32428309778488973, 0.1943000359545732)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1890, 'Type': 6, 'Coordinates': [(0.3260052283371959, 0.19307787878842048), (0.3260052283371959, 0.19307787878842048)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1891, 'Type': 6, 'Coordinates': [(0.3298383576310387, 0.1823562272853531), (0.3298383576310387, 0.1823562272853531)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1892, 'Type': 6, 'Coordinates': [(0.330782751804884, 0.18452277862535116), (0.330782751804884, 0.18452277862535116)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1893, 'Type': 6, 'Coordinates': [(0.33522695968180305, 0.17402333751612975), (0.33522695968180305, 0.17402333751612975)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1894, 'Type': 6, 'Coordinates': [(0.333171513538728, 0.1737455745238223), (0.333171513538728, 0.1737455745238223)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1895, 'Type': 6, 'Coordinates': [(0.33122717259257584, 0.17385667972074526), (0.33122717259257584, 0.17385667972074526)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1896, 'Type': 6, 'Coordinates': [(0.3412821929141054, 0.17646765184843527), (0.3412821929141054, 0.17646765184843527)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1897, 'Type': 6, 'Coordinates': [(0.3423932448833351, 0.17857865058997183), (0.3423932448833351, 0.17857865058997183)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1898, 'Type': 6, 'Coordinates': [(0.34278211307256556, 0.17652320444689676), (0.34278211307256556, 0.17652320444689676)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1899, 'Type': 6, 'Coordinates': [(0.35344821197717147, 0.19813316524841595), (0.35344821197717147, 0.19813316524841595)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1900, 'Type': 6, 'Coordinates': [(0.34900400410025234, 0.20079968997456743), (0.34900400410025234, 0.20079968997456743)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1901, 'Type': 6, 'Coordinates': [(0.3498372930771747, 0.19957753280841467), (0.3498372930771747, 0.19957753280841467)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1902, 'Type': 6, 'Coordinates': [(0.345781953389486, 0.19952198020995318), (0.345781953389486, 0.19952198020995318)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1903, 'Type': 6, 'Coordinates': [(0.34650413716948536, 0.1969665606807247), (0.34650413716948536, 0.1969665606807247)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1904, 'Type': 6, 'Coordinates': [(0.3453930852002556, 0.19402227296226576), (0.3453930852002556, 0.19402227296226576)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1905, 'Type': 6, 'Coordinates': [(0.3323937771602672, 0.1696902348361336), (0.3323937771602672, 0.1696902348361336)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1906, 'Type': 6, 'Coordinates': [(0.33489364409103417, 0.1706901816084404), (0.33489364409103417, 0.1706901816084404)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1907, 'Type': 6, 'Coordinates': [(0.3403427659848568, 0.201712462023127), (0.3403427659848568, 0.201712462023127)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1908, 'Type': 6, 'Coordinates': [(0.3467868674063896, 0.20765659005850634), (0.3467868674063896, 0.20765659005850634)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1909, 'Type': 6, 'Coordinates': [(0.34573136803562127, 0.20571224911235422), (0.34573136803562127, 0.20571224911235422)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1910, 'Type': 6, 'Coordinates': [(0.3436203692940847, 0.20487896013543191), (0.3436203692940847, 0.20487896013543191)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1911, 'Type': 6, 'Coordinates': [(0.34956449732946404, 0.21410069148003905), (0.34956449732946404, 0.21410069148003905)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1912, 'Type': 6, 'Coordinates': [(0.3486201031556187, 0.2112675089585031), (0.3486201031556187, 0.2112675089585031)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1913, 'Type': 6, 'Coordinates': [(0.3478979193756193, 0.21254521872311735), (0.3478979193756193, 0.21254521872311735)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1914, 'Type': 6, 'Coordinates': [(0.34073163417408725, 0.20804545824773676), (0.34073163417408725, 0.20804545824773676)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1915, 'Type': 6, 'Coordinates': [(0.3480645771710038, 0.20971203620158144), (0.3480645771710038, 0.20971203620158144)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1916, 'Type': 6, 'Coordinates': [(0.34484252646023744, 0.18893536437698452), (0.34484252646023744, 0.18893536437698452)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1917, 'Type': 6, 'Coordinates': [(0.3431203959079313, 0.1896575481569839), (0.3431203959079313, 0.1896575481569839)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1918, 'Type': 6, 'Coordinates': [(0.34178713354485557, 0.18793541760467775), (0.34178713354485557, 0.18793541760467775)], 'Color': '#ff00ff', 'Fixed Value': 1}
# {'Active': 1, 'Index': 1919, 'Type': 6, 'Coordinates': [(0.3367873996833215, 0.18432449870468096), (0.3367873996833215, 0.18432449870468096)], 'Color': '#ff00ff', 'Fixed Value': 1}
# Total number of parsing errors: 0

# %%
categorized_data = transformed_data
cd = 0
panck = 0
others = 0
cd_less = 0
for i in range(len(categorized_data)):
    if categorized_data[i]['Color'] == "#00ffff" or categorized_data[i]['Color'] == "#0000ff":
        cd += 1
    elif categorized_data[i]['Color'] == '#c0c0c0':
        cd_less += 1
    elif categorized_data[i]['Color'] == '#ff00ff':
        panck += 1
    else:
        others += 1

# %%
print('cd45+ 95%: ' + str(cd))
print('cd45+ 70%: ' + str(cd_less))
print('panck: ' + str(panck))
print('others: ' + str(others))
# Out:
# cd45+ 95%: 618
# cd45+ 70%: 0
# panck: 647
# others: 654

# %%
points_normalized = []
points_colors = []
for i in range(len(categorized_data)):
    points_normalized.append(categorized_data[i]['Coordinates'][0])
    points_colors.append(categorized_data[i]['Color'])  # Extracting color

    
max(points_normalized, key=lambda x:x[0])
# Out:
# (0.7231570864276186, 0.3027915485012299)

# %%
import cv2
import matplotlib.pyplot as plt

# Path to your image
root = "/rsrch5/home/plm/yshokrollahi/project4/RawDataset/"
image_path = f"{root}/ome-png/MS038S1.png"
# Load the image using OpenCV
image = cv2.imread(image_path)

# Get the width and height of the image
height, width, _ = image.shape

# Lists to hold normalized points (x, y) and their respective colors
points_normalized = []
points_colors = []

# Extract coordinates and colors from categorized_data
for i in range(len(categorized_data)):
    points_normalized.append(categorized_data[i]['Coordinates'][0])
    points_colors.append(categorized_data[i]['Color'])  # Extracting color

# Convert normalized coordinates to pixel values
points_pixel = [(int(x * width), int(y * width)) for x, y in points_normalized]

plt.figure(figsize=(10, 10))

# Display the image
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

print(f'all points: {len(points_pixel)}')
points_shown = 0

# Plot the points on the image with their respective colors
for (x, y), color in zip(points_pixel, points_colors):
    plt.scatter(x, y, c=color, marker='o', s=2)  # Using extracted color for each point
    points_shown += 1

print(f' points shown: {points_shown}')

plt.axis("off")
# plt.savefig("/Users/yshokrollahi/Desktop/MD/Project3/dataset/IF/ROIs/28/MS028S1.png")    
# Show the image with points
plt.show()
# Out:
# all points: 1919
#  points shown: 1919

# %% [markdown]
# # Save annotaions vs patches

# %%
import os
import cv2
import numpy as np

# Function to create patches and save images and annotations
def create_patches_and_save_annotations(image_path, annotations, patch_size=640, output_folder="output"):
    # Ensure output directories exist
    os.makedirs(output_folder, exist_ok=True)
    os.makedirs(os.path.join(output_folder, "images"), exist_ok=True)
    os.makedirs(os.path.join(output_folder, "annotations"), exist_ok=True)

    # Read the image
    image = cv2.imread(image_path)
    img_height, img_width = image.shape[:2]

    # Function to get label from color
    def get_label_from_color(color):
        if color == '#00ffff' or color == '#0000ff':
            return '0'
        elif color == '#ff00ff':
            return '1'
        else:
            return '2'

    patch_idx = 1

    for y in range(0, img_height, patch_size):
        for x in range(0, img_width, patch_size):
            # Handle overlap for last row and column
            if y + patch_size > img_height:
                y = img_height - patch_size
            if x + patch_size > img_width:
                x = img_width - patch_size
            
            # Extract patch
            patch = image[y:y+patch_size, x:x+patch_size]

            # Extract annotations for the patch
            patch_annotations = []
            for annotation in annotations:
                for coord, color in zip(annotation['Coordinates'], [annotation['Color']]):
                    coord_x = coord[0] * img_width
                    coord_y = coord[1] * img_width
                    if x <= coord_x < x + patch_size and y <= coord_y < y + patch_size:
                        local_x = coord_x - x
                        local_y = coord_y - y
                        label = get_label_from_color(color)
                        patch_annotations.append((label, local_x, local_y))
            
            # Only save the patch and annotations if there are annotations available
            if patch_annotations:
                patch_filename = f"patch_{patch_idx}.png"
                patch_filepath = os.path.join(output_folder, "images", patch_filename)
                cv2.imwrite(patch_filepath, patch)

                patch_annotation_filename = f"patch_{patch_idx}.txt"
                patch_annotation_filepath = os.path.join(output_folder, "annotations", patch_annotation_filename)
                with open(patch_annotation_filepath, 'w') as f:
                    for label, local_x, local_y in patch_annotations:
                        f.write(f"{label} {local_x / patch_size} {local_y / patch_size} {50 / patch_size} {50 / patch_size}\n")

                patch_idx += 1

# Example usage
image_path = f"{root}/ome-png/MS038S1.png"  # Replace with your image path
output_folder = f"{root}/ome-png/38_patches/"  # Replace with your output folder path

# Use the already transformed data (assuming transformed_data is the output from the previous cell)
create_patches_and_save_annotations(image_path, transformed_data, patch_size=640, output_folder=output_folder)

# %% [markdown]
# # verfiy

# %%
import cv2
import matplotlib.pyplot as plt
i = 27
image_path = f"{root}/ome-png/38_patches/images/patch_{i}.png"
image = cv2.imread(image_path)

# Get image dimensions (height, width)
height, width, channels = image.shape

# Convert image dimensions from pixels to inches for matplotlib (figure size in inches)
dpi = 600  # You can adjust this value to increase or decrease the image quality
figsize = width / float(dpi), height / float(dpi)

text_file_path = f"{root}/ome-png/38_patches/annotations/patch_{i}.txt"

colors = {
    '0': (0, 0, 255),
    '1': (255, 255, 0),
    '2': (255, 0, 255)
}

with open(text_file_path, 'r') as file:
    lines = file.readlines()

for line in lines:
    values = line.strip().split(' ')
    if len(values) == 5:
        label, x_center, y_center, width, height = map(float, values)

        image_width, image_height = 640, 640

        x_center *= image_width
        y_center *= image_height

        color = colors.get(str(int(label)), (0, 0, 255))

        cv2.circle(image, (int(x_center), int(y_center)), radius=4, color=color, thickness=-1)

# Convert the image from BGR to RGB
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Create a figure with the specified size and DPI
plt.figure(figsize=figsize, dpi=dpi)
plt.imshow(image_rgb)
plt.axis('off')  # Hide the axis
plt.tight_layout(pad=0)  # Remove whitespace

# Specify your save path
# save_path = f'/Users/yshokrollahi/Desktop/MD/Project3/dataset/IF/ROIs/Validation_By_Pathologist/Maria/{name}/prediction/{name}_PATCH_{patch}.png'
# plt.savefig(save_path, bbox_inches='tight', pad_inches=0, dpi=dpi)

# Optionally, you can still display the image in the notebook with plt.show()
# plt.show()

# %%
import numpy as np
from scipy.optimize import least_squares

# Known points in the old image (width = 11380)
p1_old = np.array([0.022304532353241945 * 11380, 0.941908502262405 * 11380])
p2_old = np.array([0.6594887308534805 * 11380, 0.859893126731165 * 11380])


# Known points in the new image (width = 16384)
p1_new = np.array([0.1677566319301885 * 16384, 0.6940139430968255 * 16384])
p2_new = np.array([0.6108605253843963 * 16384, 0.6369897015643509 * 16384])

# Function to model the affine transformation
def affine_transform(params, src, dst):
    a, b, tx, ty = params
    transformed = np.dot(np.array([[a, -b], [b, a]]), src.T).T + [tx, ty]
    return (transformed - dst).ravel()

# Initial guess for the parameters
initial_params = [1, 0, 0, 0]

# Solve for the transformation parameters
result = least_squares(affine_transform, initial_params, args=(np.array([p1_old, p2_old]), np.array([p1_new, p2_new])))

# Extract and print the final parameters
a, b, tx, ty = result.x
print(f"Final parameters: a = {a}, b = {b}, tx = {tx}, ty = {ty}")

# Define the affine transformation matrix
transformation_matrix = np.array([[a, 0, tx], [0, a, ty]])

# Display the transformation matrix
print(f"Affine Transformation Matrix:\n{transformation_matrix}")

# Function to apply the affine transformation to a point
def apply_affine_transform(point, matrix):
    point_homogeneous = np.append(point, 1)  # Convert to homogeneous coordinates
    transformed_point = np.dot(matrix, point_homogeneous)
    return transformed_point[:2]

# Specific coordinates to convert
old_coords = np.array([0.4679197132153972 * 11380, 0.14386079704246196 * 11380])


# Apply the affine transformation to the specific coordinates
transformed_coords = apply_affine_transform(old_coords, transformation_matrix)

# Convert to normalized coordinates in the new image
normalized_coords = (transformed_coords[0] / 16384, transformed_coords[1] / 16384)

# Print the converted coordinates
print(f"Transformed coordinates in the new image: {normalized_coords}")
# Out:
# Final parameters: a = 1.0011911505123394, b = 2.2278200245832535e-05, tx = 2494.6355331152804, ty = 639.0321876075319
# Affine Transformation Matrix:
# [[1.00119115e+00 0.00000000e+00 2.49463553e+03]
#  [0.00000000e+00 1.00119115e+00 6.39032188e+02]]
# Transformed coordinates in the new image: (0.47765531361329727, 0.1390452962146898)
